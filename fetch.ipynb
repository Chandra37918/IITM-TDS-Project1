# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
import requests
import csv
import time

# GitHub API token
GITHUB_TOKEN = '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'
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

# Helper function to clean up company names
def clean_company_name(company):
    if company:
        company = company.strip().lstrip('@').upper()
    return company

# Function to fetch users from the GitHub API
def fetch_users(city="Beijing", min_followers=500):
    users = []
    page = 1

    while True:
        url = f"https://api.github.com/search/users?q=location:{city}+followers:>{min_followers}&page={page}&per_page=100"
        response = requests.get(url, headers=HEADERS)
        data = response.json()

        # Break if no more results
        if 'items' not in data or not data['items']:
            break

        for user in data['items']:
            # Get full user info
            user_url = user['url']
            user_response = requests.get(user_url, headers=HEADERS)
            user_data = user_response.json()

            # Extract required fields
            users.append({
                'login': user_data['login'],
                'name': user_data['name'],
                'company': clean_company_name(user_data['company']),
                'location': user_data['location'],
                'email': user_data['email'],
                'hireable': user_data['hireable'],
                'bio': user_data['bio'],
                'public_repos': user_data['public_repos'],
                'followers': user_data['followers'],
                'following': user_data['following'],
                'created_at': user_data['created_at'],
            })
        page += 1
        time.sleep(1)  # Avoid hitting API rate limits

    return users

# Function to fetch repositories for a user
def fetch_repositories(user_login):
    repositories = []
    page = 1

    while True:
        url = f"https://api.github.com/users/{user_login}/repos?per_page=100&page={page}"
        response = requests.get(url, headers=HEADERS)
        repo_data = response.json()

        # Break if no more repositories
        if not repo_data:
            break

        for repo in repo_data:
            repositories.append({
                'login': user_login,
                'full_name': repo['full_name'],
                'created_at': repo['created_at'],
                'stargazers_count': repo['stargazers_count'],
                'watchers_count': repo['watchers_count'],
                'language': repo['language'],
                'has_projects': repo['has_projects'],
                'has_wiki': repo['has_wiki'],
                'license_name': repo['license']['key'] if repo['license'] else None,
            })

        # If fewer than 100 repositories are returned, it means we're on the last page
        if len(repo_data) < 100:
            break

        page += 1  # Move to the next page
        time.sleep(1)  # Avoid hitting API rate limits

    return repositories

# Save users to CSV
def save_users_to_csv(users, filename="users.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=users[0].keys())
        writer.writeheader()
        writer.writerows(users)

# Save repositories to CSV
def save_repositories_to_csv(repositories, filename="repositories.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=repositories[0].keys())
        writer.writeheader()
        writer.writerows(repositories)

def main():
    print("Fetching users...")
    users = fetch_users()
    save_users_to_csv(users)
    print(f"Saved {len(users)} users to users.csv")

    print("Fetching repositories...")
    all_repositories = []
    for user in users:
        user_repos = fetch_repositories(user["login"])
        all_repositories.extend(user_repos)
        print(f"Fetched {len(user_repos)} repositories for user {user['login']}")

    save_repositories_to_csv(all_repositories)
    print(f"Saved {len(all_repositories)} repositories to repositories.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Saved 360 users to users.csv
# Fetching repositories...
# Fetched 99 repositories for user michaelliao
# Fetched 89 repositories for user daimajia
# Fetched 55 repositories for user xiaolai
# Fetched 50 repositories for user draveness
# Fetched 102 repositories for user hongyangAndroid
# Fetched 24 repositories for user haoel
# Fetched 86 repositories for user wizardforcel
# Fetched 902 repositories for user i5ting
# Fetched 145 repositories for user 521xueweihan
# Fetched 28 repositories for user ityouknow
# Fetched 81 repositories for user PKUFlyingPig
# Fetched 26 repositories for user singwhatiwanna
# Fetched 43 repositories for user tangqiaoboy
# Fetched 48 repositories for user gaoxiang12
# Fetched 73 repositories for user liuhuanyong
# Fetched 102 repositories for user yanhaijing
# Fetched 116 repositories for user HcySunYang
# Fetched 6 repositories for user julycoding
# Fetched 59 repositories for user jindongwang
# Fetched 322 repositories for user rfyiamcool
# Fetched 34 repositories for user Terry-Mao
# Fetched 301 repositories for user chyyuu
# Fetched 183 repositories for user cch123
# Fetched 42 repositories for user rootsongjc
# Fetched 27 repositories for user ymcui
# Fetched 76 repositories for user dongweiming
# Fetched 206 repositories for user zce
# Fetched 124 repositories for user wu-sheng
# Fetched 29 repositories for user sunnyxx
# Fetched 46 repositories for user wangfupeng1988
# Fetched 31 repositories for user johnlui
# Fetched 232 repositories for user lilydjwg
# Fetched 232 repositories for user thunlp
# Fetched 25 repositories for user zhengmin1989
# Fetched 58 repositories for user baoyongzhang
# Fetched 34 repositories for user wendux
# Fetched 15 repositories for user shenghy
# Fetched 128 repositories for user polaris1119
# Fetched 74 repositories for user dexteryy
# Fetched 91 repositories for user lotem
# Fetched 89 repositories for user yangfuhai
# Fetched 54 repositories for user hiyouga
# Fetched 115 repositories for user bennyhuo
# Fetched 316 repositories for user soulteary
# Fetched 62 repositories for user taowen
# Fetched 19 repositories for user Yixiaohan
# Fetched 3 repositories for user ouyangzhiping
# Fetched 15 repositories for user foolwood
# Fetched 114 repositories for user baidu
# Fetched 51 repositories for user ideawu
# Fetched 43 repositories for user chaoslawful
# Fetched 50 repositories for user bestswifter
# Fetched 67 repositories for user shibing624
# Fetched 50 repositories for user hyper0x
# Fetched 155 repositories for user L1aoXingyu
# Fetched 7 repositories for user terrymanu
# Fetched 62 repositories for user icarusion
# Fetched 261 repositories for user MartinRGB
# Fetched 46 repositories for user dsxNiubility
# Fetched 15 repositories for user BaiduFE
# Fetched 79 repositories for user WangYihang
# Fetched 56 repositories for user Xyntax
# Fetched 102 repositories for user xiaojue
# Fetched 43 repositories for user AmazingAng
# Fetched 42 repositories for user jayli
# Fetched 62 repositories for user su18
# Fetched 350 repositories for user cucygh
# Fetched 12 repositories for user doyoe
# Fetched 231 repositories for user PegasusWang
# Fetched 131 repositories for user ksky521
# Fetched 93 repositories for user yanyiwu
# Fetched 3 repositories for user zibuyu
# Fetched 39 repositories for user kejun
# Fetched 90 repositories for user ashawkey
# Fetched 56 repositories for user meituan
# Fetched 62 repositories for user yu199195
# Fetched 52 repositories for user YouXianMing
# Fetched 10 repositories for user qiurunze123
# Fetched 81 repositories for user mocheng
# Fetched 36 repositories for user HeYijia
# Fetched 1 repositories for user liuxinyu95
# Fetched 42 repositories for user shuzheng
# Fetched 18 repositories for user xingshaocheng
# Fetched 240 repositories for user Zheaoli
# Fetched 66 repositories for user willard-yuan
# Fetched 69 repositories for user Vonng
# Fetched 25 repositories for user lcdevelop
# Fetched 21 repositories for user ericzhang-cn
# Fetched 18 repositories for user looly
# Fetched 159 repositories for user hua1995116
# Fetched 71 repositories for user spencerwooo
# Fetched 83 repositories for user didi
# Fetched 38 repositories for user ddiu8081
# Fetched 42 repositories for user Q1mi
# Fetched 151 repositories for user FASTSHIFT
# Fetched 48 repositories for user zsdonghao
# Fetched 70 repositories for user taizilongxu
# Fetched 83 repositories for user hongqn
# Fetched 196 repositories for user ZhangHanDong
# Fetched 20 repositories for user lyhue1991
# Fetched 37 repositories for user ConardLi
# Fetched 6 repositories for user lijin-THU
# Fetched 19 repositories for user youngsoft
# Fetched 28 repositories for user HanXiaoyang
# Fetched 226 repositories for user drmingdrmer
# Fetched 22 repositories for user zhanxiaokai
# Fetched 25 repositories for user netxfly
# Fetched 59 repositories for user huandu
# Fetched 41 repositories for user gavinkwoe
# Fetched 151 repositories for user ZhaoKaiQiang
# Fetched 81 repositories for user Charmve
# Fetched 8 repositories for user ShowMeAI-Hub
# Fetched 26 repositories for user nwind
# Fetched 462 repositories for user cyndibaby905
# Fetched 20 repositories for user zema1
# Fetched 33 repositories for user cystanford
# Fetched 860 repositories for user xiaoweiruby
# Fetched 48 repositories for user whyour
# Fetched 66 repositories for user ChenChenJoke
# Fetched 76 repositories for user sunfusheng
# Fetched 11 repositories for user zxh0
# Fetched 34 repositories for user danpovey
# Fetched 62 repositories for user wangrunji0408
# Fetched 49 repositories for user lipengzhou
# Fetched 52 repositories for user chaitin
# Fetched 158 repositories for user reeze
# Fetched 20 repositories for user Sophia-11
# Fetched 84 repositories for user DianQK
# Fetched 25 repositories for user neil3d
# Fetched 72 repositories for user pezy
# Fetched 51 repositories for user huxiaoman7
# Fetched 47 repositories for user anjoy8
# Fetched 30 repositories for user aa65535
# Fetched 38 repositories for user welefen
# Fetched 75 repositories for user MiCode
# Fetched 16 repositories for user vincent4j
# Fetched 64 repositories for user Naituw
# Fetched 32 repositories for user zxlie
# Fetched 58 repositories for user tuna
# Fetched 497 repositories for user msnh2012
# Fetched 9 repositories for user tristaZero
# Fetched 189 repositories for user chemzqm
# Fetched 34 repositories for user Meituan-Dianping
# Fetched 158 repositories for user wfnuser
# Fetched 75 repositories for user francistao
# Fetched 64 repositories for user youkaichao
# Fetched 119 repositories for user bsspirit
# Fetched 187 repositories for user tao12345666333
# Fetched 75 repositories for user mxdldev
# Fetched 58 repositories for user JerryLead
# Fetched 87 repositories for user fuergaosi233
# Fetched 42 repositories for user triaquae
# Fetched 47 repositories for user maotoumao
# Fetched 38 repositories for user guobinhit
# Fetched 40 repositories for user henrymorgen
# Fetched 53 repositories for user imDazui
# Fetched 118 repositories for user the5fire
# Fetched 37 repositories for user githubhaohao
# Fetched 30 repositories for user ysc
# Fetched 146 repositories for user ouuan
# Fetched 9 repositories for user GeekZooStudio
# Fetched 77 repositories for user lijiarui
# Fetched 48 repositories for user coocood
# Fetched 43 repositories for user lxfater
# Fetched 31 repositories for user johnil
# Fetched 278 repositories for user mozillazg
# Fetched 5 repositories for user wyzxxz
# Fetched 158 repositories for user sunng87
# Fetched 25 repositories for user renzifeng
# Fetched 8 repositories for user ZhongTaoTian
# Fetched 127 repositories for user EryouHao
# Fetched 269 repositories for user HuangCongQing
# Fetched 24 repositories for user yipianfengye
# Fetched 97 repositories for user wangrongding
# Fetched 26 repositories for user guolinke
# Fetched 8 repositories for user sfzhang15
# Fetched 38 repositories for user pyloque
# Fetched 91 repositories for user materliu
# Fetched 25 repositories for user cleardusk
# Fetched 270 repositories for user hardfist
# Fetched 1842 repositories for user LinuxSuRen
# Fetched 62 repositories for user WinMin
# Fetched 90 repositories for user rcore-os
# Fetched 106 repositories for user lookingstars
# Fetched 42 repositories for user qfish
# Fetched 126 repositories for user lefex
# Fetched 29 repositories for user sunner
# Fetched 6 repositories for user cymcsg
# Fetched 100 repositories for user laiwei
# Fetched 100 repositories for user qinix
# Fetched 161 repositories for user GuoYongfeng
# Fetched 97 repositories for user 2betop
# Fetched 129 repositories for user ezshine
# Fetched 4 repositories for user EllanJiang
# Fetched 50 repositories for user cmzy
# Fetched 30 repositories for user unixhot
# Fetched 53 repositories for user jiangxin
# Fetched 45 repositories for user race604
# Fetched 21 repositories for user Chuyu-Team
# Fetched 48 repositories for user virusdefender
# Fetched 99 repositories for user stanzhai
# Fetched 61 repositories for user DeveloperLx
# Fetched 31 repositories for user maxzhang
# Fetched 58 repositories for user shenzhe
# Fetched 136 repositories for user slievrly
# Fetched 146 repositories for user tianyucoder
# Fetched 34 repositories for user xianyi
# Fetched 68 repositories for user zhuzilin
# Fetched 153 repositories for user zswang
# Fetched 34 repositories for user danfenghong
# Fetched 356 repositories for user vivian8725118
# Fetched 12 repositories for user guanzhi
# Fetched 68 repositories for user killop
# Fetched 29 repositories for user TyCoding
# Fetched 13 repositories for user TIGERB
# Fetched 56 repositories for user hujiulong
# Fetched 294 repositories for user Sharpiless
# Fetched 46 repositories for user maoruibin
# Fetched 44 repositories for user motianhuo
# Fetched 102 repositories for user mritd
# Fetched 31 repositories for user ftiasch
# Fetched 123 repositories for user xuexb
# Fetched 59 repositories for user singgel
# Fetched 50 repositories for user zTrix
# Fetched 38 repositories for user lancy
# Fetched 173 repositories for user liguge
# Fetched 80 repositories for user longcw
# Fetched 48 repositories for user idealclover
# Fetched 94 repositories for user Fallen-Breath
# Fetched 29 repositories for user babysor
# Fetched 37 repositories for user yinxin630
# Fetched 45 repositories for user lw-lin
# Fetched 77 repositories for user picoxr
# Fetched 18 repositories for user Smilexuhc
# Fetched 28 repositories for user pangudashu
# Fetched 41 repositories for user rpplusplus
# Fetched 33 repositories for user hi-dhl
# Fetched 19 repositories for user etheranl
# Fetched 4 repositories for user SkyWorkAIGC
# Fetched 61 repositories for user thu-ml
# Fetched 200 repositories for user jasl
# Fetched 51 repositories for user neoremind
# Fetched 75 repositories for user hijiangtao
# Fetched 10 repositories for user tan-xu
# Fetched 9 repositories for user taichiCourse01
# Fetched 127 repositories for user ducafecat
# Fetched 23 repositories for user kedebug
# Fetched 30 repositories for user zeyangli
# Fetched 139 repositories for user alienzhou
# Fetched 13 repositories for user xinliangnote
# Fetched 106 repositories for user lizelu
# Fetched 14 repositories for user an-tao
# Fetched 94 repositories for user WillemJiang
# Fetched 6 repositories for user DreamSourceLab
# Fetched 30 repositories for user wang-xinyu
# Fetched 173 repositories for user opsnull
# Fetched 80 repositories for user bigeagle
# Fetched 48 repositories for user Sunny-117
# Fetched 4 repositories for user ireader
# Fetched 60 repositories for user adlered
# Fetched 23 repositories for user shiyanhui
# Fetched 45 repositories for user xiaye13579
# Fetched 131 repositories for user 7heaven
# Fetched 89 repositories for user UlricQin
# Fetched 82 repositories for user XuehaiPan
# Fetched 77 repositories for user xlvector
# Fetched 200 repositories for user AbangLZU
# Fetched 98 repositories for user dalinvip
# Fetched 29 repositories for user TsinghuaDatabaseGroup
# Fetched 49 repositories for user shenfeng
# Fetched 352 repositories for user qhduan
# Fetched 72 repositories for user magic-akari
# Fetched 63 repositories for user sshwsfc
# Fetched 59 repositories for user limodou
# Fetched 34 repositories for user rainx
# Fetched 47 repositories for user cundong
# Fetched 37 repositories for user wangleiphy
# Fetched 28 repositories for user wangbin579
# Fetched 4 repositories for user qgy18
# Fetched 26 repositories for user Tsinghua-MARS-Lab
# Fetched 15 repositories for user huangrt01
# Fetched 21 repositories for user r00t4dm
# Fetched 1058 repositories for user hailiang-wang
# Fetched 9 repositories for user netease-youdao
# Fetched 259 repositories for user yanqiangmiffy
# Fetched 123 repositories for user thu
# Fetched 51 repositories for user myliang
# Fetched 13 repositories for user bash-c
# Fetched 74 repositories for user kalasoo
# Fetched 453 repositories for user lsongdev
# Fetched 40 repositories for user chenryn
# Fetched 38 repositories for user DuLinRain
# Fetched 59 repositories for user BrikerMan
# Fetched 77 repositories for user ScienJus
# Fetched 28 repositories for user robin
# Fetched 13 repositories for user utom
# Fetched 34 repositories for user CatKang
# Fetched 89 repositories for user Pana
# Fetched 75 repositories for user overmind1980
# Fetched 7 repositories for user lipangit
# Fetched 163 repositories for user imfht
# Fetched 23 repositories for user hubo1016
# Fetched 23 repositories for user PhantomThief
# Fetched 22 repositories for user disksing
# Fetched 25 repositories for user meolu
# Fetched 417 repositories for user fancyerii
# Fetched 16 repositories for user lanbing510
# Fetched 463 repositories for user zhufengnodejs
# Fetched 45 repositories for user Apache9
# Fetched 6 repositories for user jimmysoa
# Fetched 58 repositories for user sumory
# Fetched 35 repositories for user q191201771
# Fetched 11 repositories for user nice0e3
# Fetched 34 repositories for user SmartDengg
# Fetched 610 repositories for user wanglong
# Fetched 44 repositories for user CreditTone
# Fetched 39 repositories for user guoyaohua
# Fetched 10 repositories for user leerumor
# Fetched 10 repositories for user wuyawei
# Fetched 68 repositories for user wszqkzqk
# Fetched 66 repositories for user icexin
# Fetched 100 repositories for user ZhaoJ9014
# Fetched 176 repositories for user cyyself
# Fetched 24 repositories for user dataabc
# Fetched 5 repositories for user Ajian-studio
# Fetched 47 repositories for user rootclay
# Fetched 44 repositories for user CharlesShang
# Fetched 83 repositories for user lizheming
# Fetched 117 repositories for user tonyseek
# Fetched 21 repositories for user ydsf16
# Fetched 4 repositories for user pennyliang
# Fetched 19 repositories for user chengdazhi
# Fetched 233 repositories for user XueshiQiao
# Fetched 12 repositories for user wh0amitz
# Fetched 89 repositories for user Ming-Lian
# Fetched 26 repositories for user errorrik
# Fetched 41 repositories for user aliaszz
# Fetched 70 repositories for user Qihoo360
# Fetched 301 repositories for user liubin
# Fetched 9 repositories for user joy0304
# Fetched 63 repositories for user windstormeye
# Fetched 34 repositories for user menzi11
# Fetched 12 repositories for user A7um
# Fetched 13 repositories for user xlzd
# Fetched 278 repositories for user PkuRainBow
# Fetched 122 repositories for user qcrao
# Fetched 36 repositories for user VincentWei
# Fetched 99 repositories for user Relph1119
# Fetched 22 repositories for user yxgeee
# Fetched 30 repositories for user leiurayer
# Fetched 18 repositories for user yu-changqian
# Fetched 54 repositories for user sjsdfg
# Fetched 100 repositories for user insightglacier
# Fetched 92 repositories for user xtlsoft
# Fetched 45 repositories for user JasinYip
# Fetched 27 repositories for user zythum
# Fetched 22 repositories for user zhangzichao
# Fetched 34 repositories for user fuxuemingzhu
# Fetched 33 repositories for user tcc0lin
# Fetched 16 repositories for user runner365
# Saved 32362 repositories to repositories.csv
